# %% [markdown]
# ## Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("/content/drive/MyDrive/DataClassNotebooks/Module_21_HW/deep-learning-challenge/Code/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df_reduced = application_df.drop(columns = ['EIN', 'NAME'])
df_reduced
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
unique_counts = df_reduced.nunique(axis=0)
  
print("Unique values in each column :\n",
      unique_counts)
# Out:
# Unique values in each column :
#  APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df_reduced['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    df_reduced['APPLICATION_TYPE'] = df_reduced['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df_reduced['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
df_reduced['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1

class_counts = df_reduced['CLASSIFICATION'].value_counts()

df_2 = pd.DataFrame(class_counts)
df_2.reset_index()
df_2


df_3 = df_2.loc[df_2['CLASSIFICATION'] < 10]
df_3

classifications_to_replace = df_3.index.values.tolist()

classifications_to_replace
# Out:
# ['C1235',
#  'C1237',
#  'C7210',
#  'C2400',
#  'C1720',
#  'C4100',
#  'C1257',
#  'C1600',
#  'C1260',
#  'C2710',
#  'C0',
#  'C3200',
#  'C1234',
#  'C1246',
#  'C1267',
#  'C1256',
#  'C2190',
#  'C4200',
#  'C2600',
#  'C5200',
#  'C1370',
#  'C1248',
#  'C6100',
#  'C1820',
#  'C1900',
#  'C1236',
#  'C3700',
#  'C2570',
#  'C1580',
#  'C1245',
#  'C2500',
#  'C1570',
#  'C1283',
#  'C2380',
#  'C1732',
#  'C1728',
#  'C2170',
#  'C4120',
#  'C8210',
#  'C2561',
#  'C4500',
#  'C2150']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    df_reduced['CLASSIFICATION'] = df_reduced['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df_reduced['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Other       98
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# Name: CLASSIFICATION, dtype: int64

# %%
df_reduced
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(data = df_reduced, columns = ['APPLICATION_TYPE', 'INCOME_AMT', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'SPECIAL_CONSIDERATIONS'])

# %%
dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                         1                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  ...  \
# 0                         0                    0                    0  ...
# 1                         0                    0                    1  ...
# 2                         0                    0                    0  ...
# 3                         0                    0                    1  ...
# 4                         0                    0                    1  ...
# ...                     ...                  ...                  ...  ...
# 34294                     0                    0                    0  ...
# 34295                     0                    0                    0  ...
# 34296                     0                    0                    1  ...
# 34297                     0                    0                    0  ...
# 34298                     0                    0                    1  ...
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                       0               0                      0
# 1                       0               0                      1
# 2                       0               0                      0
# 3                       0               0                      1
# 4                       1               0                      0
# ...                   ...             ...                    ...
# 34294                   0               0                      0
# 34295                   0               0                      0
# 34296                   0               0                      1
# 34297                   0               0                      0
# 34298                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                        1                         1
# 1                        0                         0
# 2                        1                         1
# 3                        0                         0
# 4                        0                         0
# ...                    ...                       ...
# 34294                    1                         1
# 34295                    1                         1
# 34296                    0                         1
# 34297                    1                         1
# 34298                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                       0                         1                         0
# 1                       0                         1                         0
# 2                       0                         1                         0
# 3                       1                         1                         0
# 4                       1                         1                         0
# ...                   ...                       ...                       ...
# 34294                   0                         1                         0
# 34295                   0                         1                         0
# 34296                   0                         1                         0
# 34297                   0                         1                         0
# 34298                   0                         1                         0
#
# [34299 rows x 72 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = dummies_df.drop(columns='IS_SUCCESSFUL')

y = dummies_df['IS_SUCCESSFUL']


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()




# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=71))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 16)                1152
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,441
# Trainable params: 1,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5852 - accuracy: 0.7124
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7268
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5520 - accuracy: 0.7279
# Epoch 4/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5501 - accuracy: 0.7290
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7319
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7312
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7315
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7312
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7318
# Epoch 10/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7327
# Epoch 11/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5442 - accuracy: 0.7320
# Epoch 12/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7321
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7324
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7341
# Epoch 15/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7338
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7339
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7341
# Epoch 18/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7328
# Epoch 19/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5409 - accuracy: 0.7344
# Epoch 20/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5411 - accuracy: 0.7347
# Epoch 21/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7360
# Epoch 22/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7363
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7335
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7346
# Epoch 25/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7342
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7364
# Epoch 27/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5395 - accuracy: 0.7352
# Epoch 28/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7362
# Epoch 29/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7358
# Epoch 30/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7353
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7357
# Epoch 32/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7358
# Epoch 33/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7358
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7351
# Epoch 35/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5388 - accuracy: 0.7358
# Epoch 36/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7367
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7376
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7358
# Epoch 39/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7368
# Epoch 40/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7383
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7367
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7365
# Epoch 43/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5371 - accuracy: 0.7386
# Epoch 44/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5375 - accuracy: 0.7362
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7367
# Epoch 46/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5371 - accuracy: 0.7365
# Epoch 47/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7379
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7378
# Epoch 49/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7385
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7364

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5549 - accuracy: 0.7320 - 1s/epoch - 4ms/step
# Loss: 0.5549043416976929, Accuracy: 0.7320116758346558

# %%
# Export our model to HDF5 file
nn_model.to_hdf('AlphabetSoupCharity.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a5efcc8bbe2b> in <module>
#       1 # Export our model to HDF5 file
# ----> 2 nn_model.to_hdf('AlphabetSoupCharity.h5')
#
# AttributeError: 'Sequential' object has no attribute 'to_hdf'
